# %%
import pandas as pd

# %%
import pandas as pd


# Membaca file csv ke dalam DataFrame
df = pd.read_csv('data_sampah_jabar.csv')

# Menampilkan DataFrame
df
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 0      1             32    JAWA BARAT                 3201
# 1      2             32    JAWA BARAT                 3202
# 2      3             32    JAWA BARAT                 3203
# 3      4             32    JAWA BARAT                 3204
# 4      5             32    JAWA BARAT                 3205
# ..   ...            ...           ...                  ...
# 238  239             32    JAWA BARAT                 3275
# 239  240             32    JAWA BARAT                 3276
# 240  241             32    JAWA BARAT                 3277
# 241  242             32    JAWA BARAT                 3278
# 242  243             32    JAWA BARAT                 3279
#
#     nama_kabupaten_kota  jumlah_produksi_sampah        satuan  tahun
# 0       KABUPATEN BOGOR                 1511.15  TON PER HARI   2015
# 1    KABUPATEN SUKABUMI                  419.01  TON PER HARI   2015
# ...

# %%
import pandas as pd

# Membaca file CSV ke dalam DataFrame
df = pd.read_csv('data_sampah_jabar.csv')

# Menampilkan DataFrame untuk memastikan kolom yang tersedia
print("Menampilkan lima baris pertama dari DataFrame:")
print(df.head())
print("\nMenampilkan nama kolom yang tersedia:")
print(df.columns)

# Memilih kolom yang diperlukan dengan nama kolom yang benar
df = df[['nama_kabupaten_kota', 'jumlah_produksi_sampah', 'tahun']]

# Menghitung total produksi sampah untuk tahun tertentu, misalnya 2020
tahun_tertentu = 2020
# Pastikan tidak ada nilai NaN yang mempengaruhi penjumlahan
total_produksi_tahun_tertentu = df[df['tahun'] == tahun_tertentu]['jumlah_produksi_sampah'].sum()

# Menampilkan hasil
print(f"\nTotal produksi sampah di Jawa Barat pada tahun {tahun_tertentu}: {total_produksi_tahun_tertentu} ton")
# Out:
# Menampilkan lima baris pertama dari DataFrame:
#    id  kode_provinsi nama_provinsi  kode_kabupaten_kota nama_kabupaten_kota  \
# 0   1             32    JAWA BARAT                 3201     KABUPATEN BOGOR
# 1   2             32    JAWA BARAT                 3202  KABUPATEN SUKABUMI
# 2   3             32    JAWA BARAT                 3203   KABUPATEN CIANJUR
# 3   4             32    JAWA BARAT                 3204   KABUPATEN BANDUNG
# 4   5             32    JAWA BARAT                 3205     KABUPATEN GARUT
#
#    jumlah_produksi_sampah        satuan  tahun
# 0                 1511.15  TON PER HARI   2015
# 1                  419.01  TON PER HARI   2015
# 2                  981.41  TON PER HARI   2015
# 3                 1895.94  TON PER HARI   2015
# 4                  464.74  TON PER HARI   2015
#
# Menampilkan nama kolom yang tersedia:
# Index(['id', 'kode_provinsi', 'nama_provinsi', 'kode_kabupaten_kota',
# ...

# %%
# 3
import pandas as pd

# Membaca file csv ke dalam DataFrame
df = pd.read_csv('data_sampah_jabar.csv')

# Memilih kolom yang diperlukan
df = df[['nama_kabupaten_kota', 'jumlah_produksi_sampah', 'tahun']]

# Menghitung total produksi sampah per tahun menggunakan iterrows
produksi_per_tahun = {}
for index, row in df.iterrows():
    tahun = row['tahun']
    jumlah = row['jumlah_produksi_sampah']
    if tahun not in produksi_per_tahun:
        produksi_per_tahun[tahun] = 0
    produksi_per_tahun[tahun] += jumlah

# Menampilkan hasil
for tahun, total in produksi_per_tahun.items():
    print(f"Total produksi sampah di Jawa Barat pada tahun {tahun}: {total} ton")
# Out:
# Total produksi sampah di Jawa Barat pada tahun 2015: 20969.269999999997 ton
# Total produksi sampah di Jawa Barat pada tahun 2016: 20969.269999999997 ton
# Total produksi sampah di Jawa Barat pada tahun 2017: 20969.269999999997 ton
# Total produksi sampah di Jawa Barat pada tahun 2018: 22772.92 ton
# Total produksi sampah di Jawa Barat pada tahun 2019: 24490.559999999998 ton
# Total produksi sampah di Jawa Barat pada tahun 2020: 25333.0 ton
# Total produksi sampah di Jawa Barat pada tahun 2021: 15735.360000000002 ton
# Total produksi sampah di Jawa Barat pada tahun 2022: nan ton
# Total produksi sampah di Jawa Barat pada tahun 2023: nan ton

# %%
import pandas as pd

# Membaca file CSV ke dalam DataFrame
df = pd.read_csv('data_sampah_jabar.csv')

# Memilih kolom yang diperlukan
df = df[['nama_kabupaten_kota', 'jumlah_produksi_sampah', 'tahun']]

# Menghitung total produksi sampah per Kota/Kabupaten per tahun menggunakan iterrows
produksi_per_kota_tahun = {}
for index, row in df.iterrows():
    kota = row['nama_kabupaten_kota']
    tahun = row['tahun']
    jumlah = row['jumlah_produksi_sampah']
    if kota not in produksi_per_kota_tahun:
        produksi_per_kota_tahun[kota] = {}
    if tahun not in produksi_per_kota_tahun[kota]:
        produksi_per_kota_tahun[kota][tahun] = 0
    produksi_per_kota_tahun[kota][tahun] += jumlah

# Menampilkan hasil
for kota, tahun_data in produksi_per_kota_tahun.items():
    for tahun, total in tahun_data.items():
        print(f"Total produksi sampah di {kota} pada tahun {tahun}: {total} ton")
# Out:
# Total produksi sampah di KABUPATEN BOGOR pada tahun 2015: 1511.15 ton
# Total produksi sampah di KABUPATEN BOGOR pada tahun 2016: 1511.15 ton
# Total produksi sampah di KABUPATEN BOGOR pada tahun 2017: 1511.15 ton
# Total produksi sampah di KABUPATEN BOGOR pada tahun 2018: 1716.8 ton
# Total produksi sampah di KABUPATEN BOGOR pada tahun 2019: 2914.65 ton
# Total produksi sampah di KABUPATEN BOGOR pada tahun 2020: 2977.0 ton
# Total produksi sampah di KABUPATEN BOGOR pada tahun 2021: 971.59 ton
# Total produksi sampah di KABUPATEN BOGOR pada tahun 2022: nan ton
# Total produksi sampah di KABUPATEN BOGOR pada tahun 2023: nan ton
# Total produksi sampah di KABUPATEN SUKABUMI pada tahun 2015: 419.01 ton
# Total produksi sampah di KABUPATEN SUKABUMI pada tahun 2016: 419.01 ton
# Total produksi sampah di KABUPATEN SUKABUMI pada tahun 2017: 419.01 ton
# Total produksi sampah di KABUPATEN SUKABUMI pada tahun 2018: 415.5 ton
# ...

# %%
import pandas as pd

# Membaca file csv ke dalam DataFrame
df = pd.read_csv('data_sampah_jabar.csv')

# Menampilkan DataFrame untuk memastikan kolom yang tersedia
print(df.head())

# Memilih kolom yang diperlukan
df = df[['Nama Kabupaten/Kota', 'Jumlah Produksi Sampah (ton)', 'Tahun']]

# Menghitung total produksi sampah untuk tahun tertentu, misalnya 2020
tahun_tertentu = 2020
total_produksi_tahun_tertentu = df[df['Tahun'] == tahun_tertentu]['Jumlah Produksi Sampah (ton)'].sum()

# Menampilkan hasil
print(f"Total produksi sampah di Jawa Barat pada tahun {tahun_tertentu}: {total_produksi_tahun_tertentu} ton")
# Out:
#    id  kode_provinsi nama_provinsi  kode_kabupaten_kota nama_kabupaten_kota  \
# 0   1             32    JAWA BARAT                 3201     KABUPATEN BOGOR
# 1   2             32    JAWA BARAT                 3202  KABUPATEN SUKABUMI
# 2   3             32    JAWA BARAT                 3203   KABUPATEN CIANJUR
# 3   4             32    JAWA BARAT                 3204   KABUPATEN BANDUNG
# 4   5             32    JAWA BARAT                 3205     KABUPATEN GARUT
#
#    jumlah_produksi_sampah        satuan  tahun
# 0                 1511.15  TON PER HARI   2015
# 1                  419.01  TON PER HARI   2015
# 2                  981.41  TON PER HARI   2015
# 3                 1895.94  TON PER HARI   2015
# 4                  464.74  TON PER HARI   2015
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 10
#       7 print(df.head())
# ...

# %%
df_total_per_tahun = pd.DataFrame(list(produksi_per_tahun.items()), columns=['Tahun', 'Total Produksi Sampah (ton)'])
df_total_per_kota_tahun = pd.DataFrame(
    [(kota, tahun, jumlah) for kota in produksi_per_kota_tahun for tahun, jumlah in produksi_per_kota_tahun[kota].items()],
    columns=['Nama Kabupaten/Kota', 'Tahun', 'Jumlah Produksi Sampah (ton)']
)
